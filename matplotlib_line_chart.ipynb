# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
from datetime import datetime

# %%
# plt.plot([1, 2, 3, 4], [10, 20, 25, 30])
# plt.title("Test Plot")
# plt.show()

# %%
# lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
# popu = [2, 17.6, 8.8, 8, 7.7, 6.7]

# plt.figure(figsize=(10, 6))  
# plt.plot(lang, popu, marker='o', color='skyblue', linestyle='-', linewidth=2)

# # Customize the chart
# plt.title('Popularity of Programming Languages', fontsize=14, pad=10)
# plt.xlabel('Programming Languages', fontsize=12)
# plt.ylabel('Popularity (%)', fontsize=12)
# plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# # Add grid for better visualization
# plt.grid(axis='y', linestyle='--', alpha=0.7)

# # Display the chart
# plt.tight_layout()  # Adjust layout to prevent clipping
# plt.show()

# %% [markdown]
# 1. Write a Python program to draw a line with suitable label in the x axis, y axis and a title

# %%
x = [1, 2, 3, 4]
y = [1,2,3,4]

plt.plot(x, y, marker='o')


plt.grid(axis='y', linestyle='--')

#plt.tight_layout()
plt.show()

# %% [markdown]
# 2. Write a Python program to draw a line using given axis values with suitable label in the x axis
# , y axis and a title

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Sample Line Chart')
plt.show()

# %% [markdown]
# 3. Write a Python program to draw a line using given axis values taken from a text file, with
# suitable label in the x axis, y axis and a title.
# Test Data:
# test.txt
# 1 2
# 2 4
# 3 1

# %%
x = [1, 2, 3]
y = [2,4,1]
plt.plot(x, y)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line Chart')
plt.show()

# %% [markdown]
# 4. Write a Python program to draw line charts of the financial data of Alphabet Inc. between
# October 3, 2016 to October 7, 2016.
# Sample Financial data (fdata.csv):
# Date,Open,High,Low,Close
# 03-10-16,774.25,776.065002,769.5,772.559998
# 04-10-16,776.030029,778.710022,772.890015,776.429993
# 05-10-16,779.309998,782.070007,775.650024,776.469971
# 06-10-16,779,780.47998,775.539978,776.859985
# 07-10-16,779.659973,779.659973,770.75,775.080017

# %%
df = pd.read_csv("fdata.csv")

df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%y')

plt.plot(df['Date'], df['Open'], label='Open', marker='o')
plt.plot(df['Date'], df['High'], label='High', marker='o')
plt.plot(df['Date'], df['Low'], label='Low', marker='o')
plt.plot(df['Date'], df['Close'], label='Close', marker='o')
#plt.plot(df['Date'], df['start'], label='Start', marker='o')
plt.plot(df['Date'], df['start'], label='Start', marker='o')

# Customize the chart
plt.title('Alphabet Inc. Financial Data (Oct 3-7, 2016)')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
#plt.xticks(rotation=45, ha='right')
plt.legend()
#plt.grid(True, linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# 5. Write a Python program to plot two or more lines on same plot with suitable legends of each
# line.

# %%
x = [1, 2, 3, 4, 5] 
y1 = [10, 20, 25, 30, 35] 
y2 = [15, 25, 35, 40, 45] 
y3 = [5, 15, 20, 25, 30]  

plt.plot(x, y1, label='Line 1 - Growth', marker='o', color='blue')
plt.plot(x, y2, label='Line 2 - Profit', marker='s', color='blue')
plt.plot(x, y3, label='Line 3 - Cost', marker='^', color='blue')

plt.legend()

plt.show()

# %% [markdown]
# 6. Write a Python program to plot two or more lines with legends, different widths and colors.

# %%
x = [1, 2, 3, 4, 5]  
y1 = [10, 20, 25, 30, 35] 
y2 = [15, 25, 35, 40, 45] 
y3 = [5, 15, 20, 25, 30]   

# Plot the lines with labels for the legend
plt.plot(x, y1, label='Line 1 - Growth', marker='o', color='blue',linewidth=3)
plt.plot(x, y2, label='Line 2 - Profit', marker='s', color='red',linewidth=1.5)
plt.plot(x, y3, label='Line 3 - Cost', marker='^', color='green',linewidth=1)

plt.legend()

plt.show()

# %% [markdown]
# 7. Write a Python program to plot two or more lines with different styles

# %%
x = [1, 2, 3, 4, 5] 
y1 = [10, 20, 25, 30, 35]  
y2 = [15, 25, 35, 40, 45]  
y3 = [5, 15, 20, 25, 30]   

# Plot the lines with labels for the legend
plt.plot(x, y1, label='Line 1 - Growth', color='blue',linewidth=3, ls='-')
plt.plot(x, y2, label='Line 2 - Profit', color='red',linewidth=1.5, ls='--')
plt.plot(x, y3, label='Line 3 - Cost', color='green',linewidth=1, ls=':')

plt.show()

# %% [markdown]
# 8. Write a Python program to plot two or more lines and set the line markers.

# %%
x = [1, 2, 3, 4, 5]  
y1 = [10, 20, 25, 30, 35]  
y2 = [15, 25, 35, 40, 45] 
y3 = [5, 15, 20, 25, 30]  

# Plot the lines with labels for the legend
plt.plot(x, y1, label='Line 1 - Growth', marker='o', color='blue',linewidth=3, ls='-')
plt.plot(x, y2, label='Line 2 - Profit', marker='s', color='red',linewidth=1.5, ls='--')
plt.plot(x, y3, label='Line 3 - Cost', marker='^', color='green',linewidth=1, ls=':')

plt.legend()

plt.show()

# %% [markdown]
# 9. Write a Python program to display the current axis limits values and set new axis values.

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 35]

plt.plot(x, y, label='Sample Line', marker='o')

current_xlim = plt.xlim()
current_ylim = plt.ylim()
print("Current X-axis limits:", current_xlim)
print("Current Y-axis limits:", current_ylim)

plt.legend()

plt.show()
# Out:
# Current X-axis limits: (np.float64(0.8), np.float64(5.2))
# Current Y-axis limits: (np.float64(8.75), np.float64(36.25))

# %% [markdown]
# 10. Write a Python program to plot quantities which have an x and y position.

# %%
x_positions = [1, 2, 3, 4, 5]
y_positions = [10, 20, 25, 30, 35]

# Plot quantities with x and y positions
plt.scatter(x_positions, y_positions, label='Quantities', color='blue', marker='o')

# Add legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# 11. Write a Python program to plot several lines with different format styles in one command
# using arrays.

# %%
x = np.array([1, 2, 3, 4, 5])
y1 = np.array([10, 20, 25, 30, 35])
y2 = np.array([5, 10, 15, 20, 25])
y3 = np.array([5, 15, 20, 25, 30])

plt.plot(x, y1, 'bo-', label='Line 1')
plt.plot(x, y2, 'gs--', label='Line 2')
plt.plot(x, y3, 'r^-.', label='Line 3')

# Or use a single plot command without label parameter, then add legend separately
# plt.plot(x, y1, 'bo-', x, y2, 'gs--', x, y3, 'r^-.')
# plt.legend(['Line 1', 'Line 2', 'Line 3'])

plt.legend()
plt.show()

# %% [markdown]
# 12. Write a Python program to create multiple types of charts

# %%
x = np.array([1, 2, 3, 4, 5])
y1 = np.array([10, 20, 25, 30, 35])
y2 = np.array([5, 10, 15, 20, 25])
categories = ['A', 'B', 'C', 'D']
values = [25, 35, 20, 20]
hist_data = np.random.randn(1000)

plt.figure(figsize=(15, 10))

# 1. Line Chart
plt.subplot(2, 3, 1)  # 2 rows, 3 columns, position 1
plt.plot(x, y1, 'b-', label='Line 1')
plt.plot(x, y2, 'r--', label='Line 2')
plt.title('Line Chart')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.grid(True)

# 2. Bar Chart
plt.subplot(2, 3, 2)
plt.bar(categories, values, color=['blue', 'green', 'red', 'purple'])
plt.title('Bar Chart')
plt.xlabel('Categories')
plt.ylabel('Values')

# 3. Scatter Chart
plt.subplot(2, 3, 3)
plt.scatter(x, y1, color='blue', label='Data 1')
plt.scatter(x, y2, color='red', label='Data 2')
plt.title('Scatter Chart')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

# 4. Pie Chart
plt.subplot(2, 3, 4)
plt.pie(values, labels=categories, autopct='%1.1f%%', colors=['blue', 'green', 'red', 'purple'])
plt.title('Pie Chart')

# 5. Histogram
plt.subplot(2, 3, 5)
plt.hist(hist_data, bins=30, color='purple', edgecolor='black')
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the charts
plt.show()

# Additional example: Box Plot
plt.figure(figsize=(8, 5))
data = [y1, y2, np.random.normal(20, 5, 5)]
plt.boxplot(data, labels=['Group 1', 'Group 2', 'Group 3'])
plt.title('Box Plot')
plt.ylabel('Values')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_42400\131150318.py:57: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=['Group 1', 'Group 2', 'Group 3'])

# %% [markdown]
# 13. Write a Python program to display the grid and draw line charts of the closing value of
# Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with
# linestyle -, width .5. and color blue.
# Date,Close
# 03-10-16,772.559998
# 04-10-16,776.429993
# 05-10-16,776.469971
# 06-10-16,776.859985
# 07-10-16,775.080017

# %%
dates = ['03-10-16', '04-10-16', '05-10-16', '06-10-16', '07-10-16']
closing_values = [772.559998, 776.429993, 776.469971, 776.859985, 775.080017]

# Convert string dates to datetime objects
dates = [datetime.strptime(date, '%d-%m-%y') for date in dates]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(dates, closing_values, 'b-o', label='Closing Value')

# Customize the grid
plt.grid(True, linestyle='-', linewidth=0.5, color='blue')

# Customize the plot
plt.title('Alphabet Inc. Closing Values (Oct 3-7, 2016)')
plt.xlabel('Date')
plt.ylabel('Closing Value (USD)')
plt.legend()

# Format the x-axis dates
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%y'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.xticks(rotation=45)

# Adjust layout to prevent label cutoff
#plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# 14. Write a Python program to display the grid and draw line charts of the closing value of
# Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with
# rendering with a larger grid (major grid) and a smaller grid (minor grid).Turn on the grid but turn
# off ticks.

# %%
dates = ['03-10-16', '04-10-16', '05-10-16', '06-10-16', '07-10-16']
closing_values = [772.559998, 776.429993, 776.469971, 776.859985, 775.080017]

# Convert string dates to datetime objects
dates = [datetime.strptime(date, '%d-%m-%y') for date in dates]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(dates, closing_values, 'b-o', label='Closing Value')

# Customize the major grid
plt.grid(True, which='major', linestyle='-', linewidth=0.5, color='blue')

# Customize the minor grid
plt.grid(True, which='minor', linestyle='--', linewidth=0.3, color='lightblue')

# Turn off ticks
plt.tick_params(left=False, bottom=False, labelleft=True, labelbottom=True)

# Customize the plot
plt.title('Alphabet Inc. Closing Values (Oct 3-7, 2016)')
plt.xlabel('Date')
plt.ylabel('Closing Value (USD)')
plt.legend()

# Format the x-axis dates
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%y'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.gca().xaxis.set_minor_locator(mdates.HourLocator(interval=12))  # Minor grid between days
plt.xticks(rotation=45)

# Set y-axis minor locator
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(0.5))  # Minor grid every 0.5 units

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# 15. Write a Python program to create multiple plots.

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = x**2

# Approach 1: Multiple subplots in one figure (2x2 grid)
plt.figure(figsize=(12, 8))

# Subplot 1: Sine wave
plt.subplot(2, 2, 1)  # 2 rows, 2 columns, position 1
plt.plot(x, y1, 'b-', label='Sine')
plt.title('Sine Wave')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)

# Subplot 2: Cosine wave
plt.subplot(2, 2, 2)
plt.plot(x, y2, 'r--', label='Cosine')
plt.title('Cosine Wave')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)

# Subplot 3: Tangent wave
plt.subplot(2, 2, 3)
plt.plot(x, y3, 'g-.', label='Tangent')
plt.title('Tangent Wave')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.ylim(-5, 5)  # Limit y-axis due to tangent's range

# Subplot 4: Quadratic function
plt.subplot(2, 2, 4)
plt.plot(x, y4, 'm:', label='Quadratic')
plt.title('Quadratic Function')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the first figure
plt.show()

# Approach 2: Multiple separate figures
# Figure 1: Sine and Cosine together
plt.figure(figsize=(8, 5))
plt.plot(x, y1, 'b-', label='Sine')
plt.plot(x, y2, 'r--', label='Cosine')
plt.title('Sine and Cosine Waves')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()

# Figure 2: Scatter plot of Quadratic
plt.figure(figsize=(8, 5))
plt.scatter(x, y4, color='purple', label='Quadratic', s=20)
plt.title('Quadratic Function (Scatter)')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()
