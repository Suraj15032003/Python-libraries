# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Write a Python programming to display a bar chart of the popularity of programming
# Languages.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]


plt.figure(figsize=(10, 6)) 
plt.bar(languages, popularity, color='skyblue')

plt.title('Popularity of Programming Languages', fontsize=14, pad=10)
plt.xlabel('Programming Languages', fontsize=12)
plt.ylabel('Popularity (%)', fontsize=12)

for i, v in enumerate(popularity):
    plt.text(i, v + 0.5, str(v), ha='center', fontsize=10)

plt.show()

# %% [markdown]
# 2. Write a Python programming to display a horizontal bar chart of the popularity of
# programming Languages.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

# Create horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(languages, popularity)

# Display the chart
plt.show()

# %% [markdown]
# 3. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Use uniform color.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.figure(figsize=(10, 6))
plt.bar(languages, popularity, color='blue')

plt.show()

# %% [markdown]
# 4. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Use different color for each bar.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

colors = ['red', 'blue', 'green', 'yellow', 'purple', 'orange']

plt.figure(figsize=(10, 6))
plt.bar(languages, popularity, color=colors)

plt.show()

# %% [markdown]
# 5. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Attach a text label above each bar displaying its popularity (float value).
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.figure(figsize=(10, 6))
bars = plt.bar(languages, popularity)

for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, height, 
             ha='center', va='bottom')

plt.show()

# %% [markdown]
# 6. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Make blue border to each bar.Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.figure(figsize=(10, 6))
plt.bar(languages, popularity, edgecolor='red', linewidth=3)

plt.show()

# %% [markdown]
# 7. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Specify the position of each bar plot.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

positions = [0, 2, 4, 6, 8, 10]  

plt.figure(figsize=(10, 6))
plt.bar(positions, popularity)

plt.xticks(positions, languages)

plt.show()

# %% [markdown]
# 8. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Select the width of each bar and their positions.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

positions = [0, 1.5, 3, 4.5, 6, 7.5] 
bar_width = 1.2  

plt.figure(figsize=(10, 6))
plt.bar(positions, popularity, width=bar_width)

plt.xticks(positions, languages)

plt.show()

# %% [markdown]
# 9. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Increase bottom margin.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.figure(figsize=(10, 6))
plt.bar(languages, popularity)

plt.subplots_adjust(bottom=0.2)

plt.show()

# %% [markdown]
# 10. Write a Python program to create bar plot of scores by group and gender. Use multiple X
# values on the same chart for men and women.
# Sample Data:
# Means (men) = (22, 30, 35, 35, 26)
# Means (women) = (25, 32, 30, 35, 29)

# %%
groups = ['Group 1', 'Group 2', 'Group 3', 'Group 4', 'Group 5']
men_means = [22, 30, 35, 35, 26]
women_means = [25, 32, 30, 35, 29]

x = np.arange(len(groups))  # Creates array [0, 1, 2, 3, 4]
bar_width = 0.35  # Width of each bar

plt.figure(figsize=(10, 6))

plt.bar(x - bar_width/2, men_means, bar_width, label='Men', color='blue')
plt.bar(x + bar_width/2, women_means, bar_width, label='Women', color='pink')


plt.xlabel('Groups')
plt.ylabel('Scores')
plt.title('Scores by Group and Gender')
plt.xticks(x, groups)  
plt.legend()

# %% [markdown]
# 11. Write a Python program to create bar plot from a DataFrame.
# Sample Data Frame:
# a b c d e
# 2 4,8,5,7,6
# 4 2,3,4,2,6
# 6 4,7,4,7,8
# 8 2,6,4,8,6
# 10 2,4,3,3,2

# %%
data = {
    'a': [2, 4, 6, 8, 10],
    'b': [4, 2, 4, 2, 2],
    'c': [8, 3, 7, 6, 4],
    'd': [5, 4, 4, 4, 3],
    'e': [7, 2, 7, 8, 6]
}
df = pd.DataFrame(data)

# Create bar plot
plt.figure(figsize=(10, 6))
df.plot(kind='bar', ax=plt.gca())

# Customize the chart
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Bar Plot from DataFrame')
plt.legend(title='Columns')

# Display the chart
plt.show()

# %% [markdown]
# 12. Write a Python program to create bar plots with error bars on the same figure. Sample Date
# Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824
# Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645

# %%
# Sample data
categories = ['A', 'B', 'C', 'D']
mean_velocity = [0.2474, 0.1235, 0.1737, 0.1824]
std_velocity = [0.3314, 0.2278, 0.2836, 0.2645]

# Set positions for bars
x = np.arange(len(categories))

# Create bar chart with error bars
plt.figure(figsize=(10, 6))
plt.bar(x, mean_velocity, yerr=std_velocity, capsize=5, color='skyblue')

# Customize the bar chart
plt.xlabel('Categories')
plt.ylabel('Mean Velocity')
plt.title('Bar Chart of Mean Velocity with Error Bars')
plt.xticks(x, categories)
plt.grid(True)

# Display the chart
plt.show()

# %% [markdown]
# 13. Write a Python program to create bar plots with errorbars on the same figure. Attach a text
# label above each bar displaying men means (integer value).
# Sample Data
# Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824
# Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645

# %%
categories = ['A', 'B', 'C', 'D']
mean_velocity = [0.2474, 0.1235, 0.1737, 0.1824]
std_velocity = [0.3314, 0.2278, 0.2836, 0.2645]

x = np.arange(len(categories))

plt.figure(figsize=(10, 6))
bars = plt.bar(x,mean_velocity, yerr=std_velocity, capsize=5, color='skyblue')


for bar, mean in zip(bars, mean_velocity):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{int(mean*100)}', 
             ha='center', va='bottom')

plt.xlabel('Categories')
plt.ylabel('Mean Velocity')
plt.title('Mean Velocity with Error Bars and Integer Labels')
plt.xticks(x, categories)

plt.show()
